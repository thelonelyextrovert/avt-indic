# %% [markdown]
# <a href="https://colab.research.google.com/github/thelonelyextrovert/avt-indic/blob/main/LSE_D_and_LSE_C_calculations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/joonson/syncnet_python.git
# Out:
# Cloning into 'syncnet_python'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 123 (delta 35), reused 28 (delta 28), pack-reused 77
# Receiving objects: 100% (123/123), 97.36 KiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# %cd syncnet_python
# !pip install -r requirements.txt
# !sh download_model.sh
# Out:
# /content/Wav2Lip/evaluation/scores_LSE/syncnet_python
# ...
#      |████████████████████████████████| 75 kB 4.6 MB/s
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=a0ad2dd4cb2f48284740815bdf78a93136d1a1d8ea209fedb5d570d7612beb49
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built python-speech-features
# ...
# --2022-04-20 13:26:14--  http://www.robots.ox.ac.uk/~vgg/software/lipsync/data/syncnet_v2.model
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/software/lipsync/data/syncnet_v2.model [following]
# --2022-04-20 13:26:14--  https://www.robots.ox.ac.uk/~vgg/software/lipsync/data/syncnet_v2.model
# ...

# %%
# %cd ..
# Out:
# /content/Wav2Lip/evaluation/scores_LSE

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 360, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 360 (delta 11), reused 16 (delta 7), pack-reused 338
# Receiving objects: 100% (360/360), 522.85 KiB | 2.48 MiB/s, done.
# Resolving deltas: 100% (195/195), done.

# %%
# %cd Wav2Lip/evaluation/scores_LSE/
# Out:
# [Errno 2] No such file or directory: 'Wav2Lip/evaluation/scores_LSE/'
# /content/Wav2Lip/evaluation/scores_LSE

# %%
# !cp *.py syncnet_python/
# !cp *.sh syncnet_python/

# %%
# %cd syncnet_python
# Out:
# /content/Wav2Lip/evaluation/scores_LSE/syncnet_python

# %%
# !sh calculate_scores_real_videos.sh /content/videodataroot
# Out:
# Streaming output truncated to the last 5000 lines.
# tmp_dir/pyavi/wav2lip/video.avi-00330; 1 dets; 37.09 Hz
# /content/Wav2Lip/evaluation/scores_LSE/syncnet_python/detectors/s3fd/box_utils.py:103: UserWarning: An output with one or more elements was resized since it had shape [21], which does not match the required output shape [5].This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  ../aten/src/ATen/native/Resize.cpp:23.)
#   torch.index_select(x1, 0, idx, out=xx1)
# ...
